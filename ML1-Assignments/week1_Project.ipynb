# %%
# importing libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load the dataset
data  = pd.read_csv("C:\\Users\\PC\\Machine-Learning-class\\DATA\\chip_dataset (1).csv")
